# %% [markdown]
# # **Part 1. Defining the Problem and System Design**

# %% [markdown]
# # **1. Select a disease fo Diagnosis**
#
# **Question: What disease did you choose and what factors contributing to diagnosing this disease?**
#
# ***Answer:***
#
# **Disease:** Diabetes
#
# **Contributing Factors:**
# - High blood sugar levels
#
# - Genetics (family history)
#
# - Obesity
#
# - Lack of exercise
#
# - Age
#
# - Hypertension

# %% [markdown]
# # **Part 2. Basic Probability Calculation**
#
# ***1. Given Information:***
#
# Prior probability (prevalence of the disease):
#
# * P(Disease)=0.02
#
# Test sensitivity (probability of a positive result given disease):
#
# * P(Positive∣Disease)=0.95
#
# False positive rate (probability of a positive result given no disease):
#
# * P(Positive∣NoDisease)=0.05
#
# Probability of a positive result in the population:
#
# * P(Positive)=0.06
#
# ***2. Computation***
#
# Substituting values into Bayes' Theorem Formula:
#
# * P(Disease∣Positive)= P(Positive∣Disease) × P(Disease) / P(Positive)
# ​
#
# Insert the values:
#
# * P(Disease∣Positive)= 0.95 × 0.02 / 0.06
#
# * 0.95 × 0.02 = 0.019
#
# * P(Disease∣Positive)= 0.019 / 0.06
#
# * P(Disease∣Positive) = 0.3167(approximately)
#
# ***3. Answer:***
#
# ***Posterior Probability:*** The posterior probability that the patient has the disease given that they tested positive is approximately **0.3167 or 31.67%**.

# %% [markdown]
# # **Part 3. Decision-Making Simulation**
#
# ***1. Given:***
#
# Probability of Success (P(Success)) = 70% = 0.7
#
# Benefit from Success = 100 points
#
# Probability of Failure (P(Failure)) = 30% = 0.3
#
# Loss from Failure = -50 points (since it's a reduction, it’s negative)
#
# ***2. Computation***:
#
# Expected Health Improvement=(0.7×100)+(0.3×(−50))
#
#
# ***3. Answer:***
#
# ***Expected Improvement:*** The expected health improvement for the patient is **55 points**.

# %% [markdown]
# # **Part 4. Visualize a Probability Distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 5
p = 0.5

x = np.arange(0, n + 1)

probabilities = binom.pmf(x, n, p)

plt.figure(figsize=(10, 6))
plt.bar(x, probabilities, color='skyblue', alpha=0.7)
plt.xticks(x)
plt.xlabel('Number of Heads', fontsize=14)
plt.ylabel('Probability', fontsize=14)
plt.title('Binomial Distribution: Probability of Getting Heads in 5 Coin Flips', fontsize=16)
plt.ylim(0, max(probabilities) + 0.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)

for i in range(len(x)):
    plt.text(x[i], probabilities[i], f'{probabilities[i]:.2f}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Part 5. Reflection**
#
# Understanding probability theory is crucial in medical diagnosis systems as it allows healthcare professionals to quantify uncertainty and assess the likelihood of various conditions based on patient data. By applying Bayesian inference, doctors can update their beliefs about a patient's likelihood of having a disease as new evidence (such as test results) emerges. This probabilistic approach aids in distinguishing between true positives and false positives, leading to more accurate diagnoses and informed treatment decisions. Ultimately, probability theory enhances decision-making by enabling a systematic evaluation of risks and benefits, improving patient outcomes.
